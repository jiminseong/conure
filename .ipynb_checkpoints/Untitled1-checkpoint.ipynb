# %%
from openai import OpenAI
import os

API_KEY = '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'
OpenAI.api_key = API_KEY
os.environ["OPENAI_API_KEY"] = OpenAI.api_key
client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
def request_chat_completion(
    prompt, 
    system_role="복통 환자를 진료하는 간호사", 
    model="gpt-4o",
    stream = True
):
    messages=[
        {"role": "system", "content": system_role},
        {"role":"user", "content": prompt}
    ]
    client = OpenAI(
    )
    chat_completion = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        stream = stream
    )
    return chat_completion

# %%
def print_streaming_response(response):
    for chunck in response:
        delta = chunck.choices[0]["delta"]
        if "content" in delta:
            print(delta["content"], end="")
        else:
            break

# %%
response = request_chat_completion("안녕하세요!")
print_streaming_response(response)
# Out:
# -----------------------------------------------------
# RateLimitError      Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = request_chat_completion("안녕하세요!")
#       2 print_streaming_response(response)
#
# Cell In[2], line 13, in request_chat_completion(prompt, system_role, model, stream)
#       7 messages=[
#       8     {"role": "system", "content": system_role},
#       9     {"role":"user", "content": prompt}
#      10 ]
#      11 client = OpenAI(
#      12 )
# ---> 13 chat_completion = client.chat.completions.create(
#      14     model="gpt-3.5-turbo",
#      15     messages=messages,
#      16     stream = stream
#      17 )
#      18 return chat_completion
#
# File ~\OneDrive\Desktop\conure\venv\Lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# ...

# %%
## 프롬프트 엔지어링

# %%
prompt = "'복통에 좋은 음식 추천해줘'"
system_role = "당신은 복통을 치료해주는 간호사입니다."
response = request_chat_completion(prompt)
print_streaming_response(response)
# Out:
# -----------------------------------------------------
# RateLimitError      Traceback (most recent call last)
# Cell In[6], line 3
#       1 prompt = "'복통에 좋은 음식 추천해줘'"
#       2 system_role = "당신은 복통을 치료해주는 간호사입니다."
# ----> 3 response = request_chat_completion(prompt)
#       4 print_streaming_response(response)
#
# Cell In[2], line 13, in request_chat_completion(prompt, system_role, model, stream)
#       7 messages=[
#       8     {"role": "system", "content": system_role},
#       9     {"role":"user", "content": prompt}
#      10 ]
#      11 client = OpenAI(
#      12 )
# ---> 13 chat_completion = client.chat.completions.create(
#      14     model="gpt-3.5-turbo",
#      15     messages=messages,
#      16     stream = stream
#      17 )
#      18 return chat_completion
#
# File ~\OneDrive\Desktop\conure\venv\Lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
# ...

# %%
prompt_template = """
음식에 따라 복통이 생긴 이유를 알려주세요
먹으면 좋을 약을 추천해주세요.
___
음식: {food_name}
___
""",strip()

# %%
food_name = "회"
prompt = prompt_template.format(
    food_name = food_name
)

# %% [raw]
# print(prompt)

# %%
respone = request_chat_completion(
    prompt, 
    system_role=system_role
)
print_streaming_resonse(response)

# %%
prompt_template_2 = """
{food} 먹었을 때 복통을 완화하는 방법을 알려주세요
먹으면 좋은 음식과 약을 추천해주세요
___
음식: {food_name}
___
""",strip()

# %%
food_name = "회"

prompt = prompt_template_3.format(
    food_name = food_name
)

# %%
respone = request_chat_completion(
    prompt, 
    system_role=system_role
)
print_streaming_resonse(response)
